# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import pearsonr

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
# check details of the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
sns.countplot(x="quality", data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
df['fixed acidity'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['fixed acidity'].min())
print('Max value', df['fixed acidity'].max())
# Out:
# Min value 4.6
# Max value 15.9

# %%
df['volatile acidity'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['volatile acidity'].min())
print('Max value', df['volatile acidity'].max())
# Out:
# Min value 0.12
# Max value 1.58

# %%
df['citric acid'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['citric acid'].min())
print('Max value', df['citric acid'].max())
# Out:
# Min value 0.0
# Max value 1.0

# %%
df['residual sugar'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['residual sugar'].min())
print('Max value',df['residual sugar'].max())
# Out:
# Min value 0.9
# Max value 15.5

# %%
df['chlorides'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['chlorides'].min())
print('Max value',df['chlorides'].max())
# Out:
# Min value 0.012
# Max value 0.611

# %%
df['free sulfur dioxide'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['free sulfur dioxide'].min())
print('Max value',df['free sulfur dioxide'].max())
# Out:
# Min value 1.0
# Max value 72.0

# %%
df['total sulfur dioxide'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['total sulfur dioxide'].min())
print('Max value',df['total sulfur dioxide'].max())
# Out:
# Min value 6.0
# Max value 289.0

# %%
df['density'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['density'].min())
print('Max value',df['density'].max())
# Out:
# Min value 0.99007
# Max value 1.00369

# %%
df['pH'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['pH'].min())
print('Max value',df['pH'].max())
# Out:
# Min value 2.74
# Max value 4.01

# %%
df['sulphates'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['sulphates'].min())
print('Max value',df['sulphates'].max())
# Out:
# Min value 0.33
# Max value 2.0

# %%
df['alcohol'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print('Min value',df['alcohol'].min())
print('Max value',df['alcohol'].max())
# Out:
# Min value 8.4
# Max value 14.9

# %%
sns.scatterplot(x='density', y='alcohol', data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='alcohol'>

# %%
sns.scatterplot(x='pH', y='alcohol', data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='alcohol'>

# %%
sns.boxplot(data=df, x='density')
# Out:
# <AxesSubplot:xlabel='density'>

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'fixed acidity', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'volatile acidity', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'residual sugar', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'citric acid', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'chlorides', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'sulphates', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'alcohol', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'pH', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(method='pearson'), annot=True, square=True)
plt.show()

# %%
print('Correlation of different features of our dataset with quality:')
for i in df.columns:
  corr, _ = pearsonr(df[i], df['quality'])
  print('%s : %.4f' %(i,corr))
# Out:
# Correlation of different features of our dataset with quality:
# fixed acidity : 0.1241
# volatile acidity : -0.3906
# citric acid : 0.2264
# residual sugar : 0.0137
# chlorides : -0.1289
# free sulfur dioxide : -0.0507
# total sulfur dioxide : -0.1851
# density : -0.1749
# pH : -0.0577
# sulphates : 0.2514
# alcohol : 0.4762
# quality : 1.0000

# %%
#for another view, this method can be used to view correlations
print('Another view of correlations among features:\n')
df.corr().style.background_gradient(cmap="coolwarm")
# Out:
# Another view of correlations among features:
# <style type="text/css">
# #T_2d87f_row0_col0, #T_2d87f_row1_col1, #T_2d87f_row2_col2, #T_2d87f_row3_col3, #T_2d87f_row4_col4, #T_2d87f_row5_col5, #T_2d87f_row6_col6, #T_2d87f_row7_col7, #T_2d87f_row8_col8, #T_2d87f_row9_col9, #T_2d87f_row10_col10, #T_2d87f_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2d87f_row0_col1, #T_2d87f_row4_col11, #T_2d87f_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_2d87f_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_2d87f_row0_col3, #T_2d87f_row4_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_2d87f_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_2d87f_row0_col5, #T_2d87f_row0_col8, #T_2d87f_row1_col2, #T_2d87f_row1_col9, #T_2d87f_row1_col11, #T_2d87f_row2_col1, #T_2d87f_row7_col10, #T_2d87f_row8_col0, #T_2d87f_row8_col3, #T_2d87f_row8_col4, #T_2d87f_row10_col6, #T_2d87f_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2d87f_row0_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_2d87f_row0_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_2d87f_row0_col9, #T_2d87f_row3_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_2d87f_row0_col10, #T_2d87f_row3_col11 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_2d87f_row0_col11, #T_2d87f_row2_col4, #T_2d87f_row7_col1, #T_2d87f_row7_col4, #T_2d87f_row10_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_2d87f_row1_col0, #T_2d87f_row3_col4, #T_2d87f_row5_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_2d87f_row1_col3, #T_2d87f_row2_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_2d87f_row1_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_2d87f_row1_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_2d87f_row1_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_2d87f_row1_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_2d87f_row1_col8 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_2d87f_row1_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_2d87f_row2_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_2d87f_row2_col3, #T_2d87f_row3_col9, #T_2d87f_row5_col4, #T_2d87f_row11_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_2d87f_row2_col6, #T_2d87f_row7_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_2d87f_row2_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_2d87f_row2_col8, #T_2d87f_row9_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_2d87f_row2_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_2d87f_row2_col10, #T_2d87f_row6_col1, #T_2d87f_row7_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_2d87f_row2_col11 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_2d87f_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_2d87f_row3_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_2d87f_row3_col2, #T_2d87f_row5_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_2d87f_row3_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_2d87f_row3_col6, #T_2d87f_row6_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_2d87f_row3_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_2d87f_row3_col10 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_2d87f_row4_col0, #T_2d87f_row9_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_2d87f_row4_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_2d87f_row4_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_2d87f_row4_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_2d87f_row4_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_2d87f_row4_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_2d87f_row4_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_2d87f_row4_col8, #T_2d87f_row5_col9, #T_2d87f_row6_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_2d87f_row4_col9, #T_2d87f_row9_col4, #T_2d87f_row11_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_2d87f_row5_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_2d87f_row5_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_2d87f_row5_col2, #T_2d87f_row5_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_2d87f_row5_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_2d87f_row5_col10, #T_2d87f_row9_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_2d87f_row5_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_2d87f_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_2d87f_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_2d87f_row6_col5 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_2d87f_row6_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_2d87f_row6_col8 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_2d87f_row6_col9, #T_2d87f_row8_col11 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_2d87f_row6_col10, #T_2d87f_row8_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_2d87f_row6_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_2d87f_row7_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_2d87f_row7_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_2d87f_row7_col5, #T_2d87f_row8_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_2d87f_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_2d87f_row7_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_2d87f_row7_col11 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_2d87f_row8_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_2d87f_row8_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_2d87f_row8_col7, #T_2d87f_row11_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_2d87f_row8_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_2d87f_row8_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_2d87f_row9_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_2d87f_row9_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_2d87f_row9_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_2d87f_row9_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_2d87f_row9_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_2d87f_row9_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_2d87f_row10_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2d87f_row10_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_2d87f_row10_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_2d87f_row10_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_2d87f_row10_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_2d87f_row10_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_2d87f_row10_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_2d87f_row10_col11 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_2d87f_row11_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_2d87f_row11_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_2d87f_row11_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_2d87f_row11_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_2d87f_row11_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_2d87f_row11_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_2d87f_row11_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_2d87f_row11_col10 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# </style>
# <table id="T_2d87f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d87f_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_2d87f_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_2d87f_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_2d87f_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_2d87f_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_2d87f_

# %%
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
df['quality'] = pd.cut(df['quality'], bins = bins, labels = group_names)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol quality
# 0         9.4     bad
# 1         9.8     bad
# 2         9.8     bad
# 3         9.8     bad
# 4         9.4     bad
# ...       ...     ...
# 1594     10.5     bad
# 1595     11.2     bad
# 1596     11.0     bad
# 1597     10.2     bad
# 1598     11.0     bad
#
# [1599 rows x 12 columns]

# %%
df['quality'] = df['quality'].map({'bad' : 0, 'good' : 1})
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol quality
# 0      9.4       0
# 1      9.8       0
# 2      9.8       0
# 3      9.8       0
# 4      9.4       0
# 5      9.4       0
# 6      9.4       0
# 7     10.0       1
# 8      9.5       1
# 9     10.5       0

# %%
print(df['quality'].value_counts())
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(18, 5))
ax = ax.flatten()
df['quality'].value_counts().plot(x=0, y=1, kind='pie', figsize=(15,5), ax=ax[0])
sns.countplot(df['quality'], ax=ax[1])
plt.show()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = df.drop('quality', axis = 1)
y = df['quality']
 
#Creating training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#Feature scaling, but not scaling dependent variable as it has categorical data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix 

# %config Completer.use_jedi = False

# %%
logreg = LogisticRegression(solver='lbfgs', random_state=42)
logreg.fit(X_train, y_train)
pred_logreg = logreg.predict(X_test)
Y_compare_logisticRegression = pd.DataFrame({'Actual' : y_test, 'Predicted' : pred_logreg})
print(Y_compare_logisticRegression.sample(5))
print('\nConfussion matrix:')
print(confusion_matrix(y_test, pred_logreg))
# Out:
#      Actual  Predicted
# 1144      0          0
# 650       0          0
# 32        0          0
# 534       0          0
# 107       0          0
#
# Confussion matrix:
# [[268   5]
#  [ 35  12]]

# %%
import itertools
def plot_confusion_matrix(cm, classes, normalize = False,
                          title='Confusion matrix',
                          cmap=plt.cm.Greens): # can change color 
    plt.figure(figsize = (5, 5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, size = 24)
    plt.colorbar(aspect=4)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, size = 14)
    plt.yticks(tick_marks, classes, size = 14)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    # Label the plot
    for i, j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
             plt.text(j, i, format(cm[i, j], fmt), 
             fontsize = 20,
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")
    
    plt.tight_layout()
    plt.ylabel('True label', size = 18)
    plt.xlabel('Predicted label', size = 18)

# Let's plot it out
cm = confusion_matrix(y_test, pred_logreg)
plot_confusion_matrix(cm, classes = ['0 - Bad', '1 - Good'],
                      title = 'Confusion Matrix')

# %%
knn = KNN(n_neighbors=2, metric='minkowski', p=2,)
knn.fit(X_train, y_train)
pred_knn = knn.predict(X_test)
Y_compare_knn = pd.DataFrame({'Actual' : y_test, 'Predicted' : pred_knn})
print(Y_compare_knn.head())
print('\nConfussion matrix:')
print(confusion_matrix(y_test, pred_knn))
# Out:
#      Actual  Predicted
# 803       0          0
# 124       0          0
# 350       0          0
# 682       0          0
# 1326      0          0
#
# Confussion matrix:
# [[266   7]
#  [ 34  13]]

# %%
cm = confusion_matrix(y_test, pred_knn)
plot_confusion_matrix(cm, classes = ['0 - Bad', '1 - Good'], title = 'Confusion Matrix')

# %%
rfc = RandomForestClassifier(n_estimators=25, criterion='gini', random_state=0,)
rfc.fit(X_train, y_train)
pred_rf = rfc.predict(X_test)
Y_compare_rfc = pd.DataFrame({'Actual' : y_test, 'Predicted' : pred_rf})
print(Y_compare_rfc.head())
print('\nConfussion matrix:')
print(confusion_matrix(y_test, pred_rf))
# Out:
#      Actual  Predicted
# 803       0          0
# 124       0          0
# 350       0          0
# 682       0          0
# 1326      0          0
#
# Confussion matrix:
# [[264   9]
#  [ 25  22]]

# %%
cm = confusion_matrix(y_test, pred_rf)
plot_confusion_matrix(cm, classes = ['0 - Bad', '1 - Good'],
                      title = 'Confusion Matrix')

# %%
#K-fold cross validation
modelNames = ['Logistic Regression', 'K-Nearest Neighbour', 'Random Forrest']
modelClassifiers = [logreg, knn,rfc]
models = pd.DataFrame({'modelNames' : modelNames, 'modelClassifiers' : modelClassifiers})
counter=0
score=[]
for i in models['modelClassifiers']:
  accuracy = cross_val_score(i, X_train, y_train, scoring='accuracy', cv=10)
  print('Accuracy of %s Classification model is %.2f' %(models.iloc[counter,0],accuracy.mean()))
  score.append(accuracy.mean())
  counter+=1
# Out:
# Accuracy of Logistic Regression Classification model is 0.89
# Accuracy of K-Nearest Neighbour Classification model is 0.89
# Accuracy of Random Forrest Classification model is 0.91

# %%
#Plotting the accuracies of different models
pd.DataFrame({'Model Name' : modelNames,'Score' : score}).sort_values(by='Score', ascending=True).plot(x=0, y=1, kind='bar', figsize=(15,5), title='Comparison of accuracies of differnt classification models')
plt.show()
